# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
x = np.arange(0, 1, 0.001)
plt.plot(x, (np.log(1-x) - np.log(x))/2)
plt.plot(x, np.zeros(x.shape))
plt.xlabel("em")
plt.ylabel("am")
# Out:
# E:\Python\lib\site-packages\ipykernel\__main__.py:2: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app
