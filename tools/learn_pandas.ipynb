# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20100101', periods=6)
dates
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-01-01</th>
#       <td>-0.784787</td>
#       <td>-1.518295</td>
#       <td>1.299667</td>
#       <td>-0.332022</td>
#     </tr>
#     <tr>
#       <th>2010-01-02</th>
#       <td>0.365641</td>
#       <td>1.391388</td>
#       <td>0.794097</td>
#       <td>2.043478</td>
#     </tr>
#     <tr>
#       <th>2010-01-03</th>
#       <td>-0.419046</td>
#       <td>0.577045</td>
#       <td>-1.754361</td>
#       <td>-0.527029</td>
#     </tr>
#     <tr>
#       <th>2010-01-04</th>
# ...

# %%
df2 = pd.DataFrame({ 'A' : 1.,  
                     'B' : pd.Timestamp('20130102'),
                     'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                     'D' : np.array([3] * 4,dtype='int32'),
                     'E' : pd.Categorical(["test","train","test","train"]),
                     'F' : 'foo' })
df2
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>train</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
# ...

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>train</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
# ...

# %%
df2.tail()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>train</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
# ...

# %%
df.index, df.columns, df.values
# Out:
# (DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                 '2010-01-05', '2010-01-06'],
#                dtype='datetime64[ns]', freq='D'),
#  Index(['A', 'B', 'C', 'D'], dtype='object'),
#  array([[-0.78478691, -1.51829459,  1.29966717, -0.33202163],
#         [ 0.36564137,  1.39138823,  0.79409703,  2.04347793],
#         [-0.41904569,  0.5770451 , -1.75436099, -0.52702877],
#         [-1.1049149 ,  1.49683481, -0.1655616 , -0.07631273],
#         [ 1.79140566,  0.01974233, -0.13465559, -1.4217528 ],
#         [ 1.56892301, -0.33038319,  0.23938073,  0.30499087]]))

# %%
df.T, df.T.values, df.sort_values(by='B')
# Out:
# (   2010-01-01  2010-01-02  2010-01-03  2010-01-04  2010-01-05  2010-01-06
#  A   -0.784787    0.365641   -0.419046   -1.104915    1.791406    1.568923
#  B   -1.518295    1.391388    0.577045    1.496835    0.019742   -0.330383
#  C    1.299667    0.794097   -1.754361   -0.165562   -0.134656    0.239381
#  D   -0.332022    2.043478   -0.527029   -0.076313   -1.421753    0.304991,
#  array([[-0.78478691,  0.36564137, -0.41904569, -1.1049149 ,  1.79140566,
#           1.56892301],
#         [-1.51829459,  1.39138823,  0.5770451 ,  1.49683481,  0.01974233,
#          -0.33038319],
#         [ 1.29966717,  0.79409703, -1.75436099, -0.1655616 , -0.13465559,
#           0.23938073],
#         [-0.33202163,  2.04347793, -0.52702877, -0.07631273, -1.4217528 ,
#           0.30499087]]),
#                     A         B         C         D
#  2010-01-01 -0.784787 -1.518295  1.299667 -0.332022
#  2010-01-06  1.568923 -0.330383  0.239381  0.304991
# ...

# %%
df['A'], df[0:3], df.loc[dates[0]]
# Out:
# (2010-01-01   -0.784787
#  2010-01-02    0.365641
#  2010-01-03   -0.419046
#  2010-01-04   -1.104915
#  2010-01-05    1.791406
#  2010-01-06    1.568923
#  Freq: D, Name: A, dtype: float64,
#                     A         B         C         D
#  2010-01-01 -0.784787 -1.518295  1.299667 -0.332022
#  2010-01-02  0.365641  1.391388  0.794097  2.043478
#  2010-01-03 -0.419046  0.577045 -1.754361 -0.527029,
#  A   -0.784787
#  B   -1.518295
#  C    1.299667
#  D   -0.332022
#  Name: 2010-01-01 00:00:00, dtype: float64)

# %%
df.loc['20100101': '20100103', ['A', 'B']]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-01-01</th>
#       <td>-0.784787</td>
#       <td>-1.518295</td>
#     </tr>
#     <tr>
#       <th>2010-01-02</th>
#       <td>0.365641</td>
#       <td>1.391388</td>
#     </tr>
#     <tr>
#       <th>2010-01-03</th>
#       <td>-0.419046</td>
#       <td>0.577045</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.iloc[:, 1:2]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-01-01</th>
#       <td>-1.518295</td>
#     </tr>
#     <tr>
#       <th>2010-01-02</th>
#       <td>1.391388</td>
#     </tr>
#     <tr>
#       <th>2010-01-03</th>
#       <td>0.577045</td>
#     </tr>
#     <tr>
#       <th>2010-01-04</th>
#       <td>1.496835</td>
#     </tr>
#     <tr>
#       <th>2010-01-05</th>
#       <td>0.019742</td>
#     </tr>
#     <tr>
#       <th>2010-01-06</th>
#       <td>-0.330383</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.iloc[:, [1,2,3]]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-01-01</th>
#       <td>-1.518295</td>
#       <td>1.299667</td>
#       <td>-0.332022</td>
#     </tr>
#     <tr>
#       <th>2010-01-02</th>
#       <td>1.391388</td>
#       <td>0.794097</td>
#       <td>2.043478</td>
#     </tr>
#     <tr>
#       <th>2010-01-03</th>
#       <td>0.577045</td>
#       <td>-1.754361</td>
#       <td>-0.527029</td>
#     </tr>
#     <tr>
#       <th>2010-01-04</th>
#       <td>1.496835</td>
#       <td>-0.165562</td>
#       <td>-0.076313</td>
#     </tr>
#     <tr>
# ...

# %%
df[df.A > 0]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-01-02</th>
#       <td>0.365641</td>
#       <td>1.391388</td>
#       <td>0.794097</td>
#       <td>2.043478</td>
#     </tr>
#     <tr>
#       <th>2010-01-05</th>
#       <td>1.791406</td>
#       <td>0.019742</td>
#       <td>-0.134656</td>
#       <td>-1.421753</td>
#     </tr>
#     <tr>
#       <th>2010-01-06</th>
#       <td>1.568923</td>
#       <td>-0.330383</td>
#       <td>0.239381</td>
#       <td>0.304991</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'five']
df2
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-01-01</th>
#       <td>-0.784787</td>
#       <td>-1.518295</td>
#       <td>1.299667</td>
#       <td>-0.332022</td>
#       <td>one</td>
#     </tr>
#     <tr>
#       <th>2010-01-02</th>
#       <td>0.365641</td>
#       <td>1.391388</td>
#       <td>0.794097</td>
#       <td>2.043478</td>
#       <td>one</td>
#     </tr>
#     <tr>
#       <th>2010-01-03</th>
#       <td>-0.419046</td>
#       <td>0.577045</td>
#       <td>-1.754361</td>
#       <td>-0.527029</td>
# ...

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-01-03</th>
#       <td>-0.419046</td>
#       <td>0.577045</td>
#       <td>-1.754361</td>
#       <td>-0.527029</td>
#       <td>two</td>
#     </tr>
#     <tr>
#       <th>2010-01-05</th>
#       <td>1.791406</td>
#       <td>0.019742</td>
#       <td>-0.134656</td>
#       <td>-1.421753</td>
#       <td>four</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range("20190909", periods=6))
s1
# Out:
# 2019-09-09    1
# 2019-09-10    2
# 2019-09-11    3
# 2019-09-12    4
# 2019-09-13    5
# 2019-09-14    6
# Freq: D, dtype: int64

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1], 'E'] = 1
df1
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-01-01</th>
#       <td>-0.784787</td>
#       <td>-1.518295</td>
#       <td>1.299667</td>
#       <td>-0.332022</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2010-01-02</th>
#       <td>0.365641</td>
#       <td>1.391388</td>
#       <td>0.794097</td>
#       <td>2.043478</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2010-01-03</th>
#       <td>-0.419046</td>
#       <td>0.577045</td>
#       <td>-1.754361</td>
#       <td>-0.527029</td>
# ...

# %%
df1.dropna()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-01-01</th>
#       <td>-0.784787</td>
#       <td>-1.518295</td>
#       <td>1.299667</td>
#       <td>-0.332022</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2010-01-02</th>
#       <td>0.365641</td>
#       <td>1.391388</td>
#       <td>0.794097</td>
#       <td>2.043478</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df1.fillna(value=5)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-01-01</th>
#       <td>-0.784787</td>
#       <td>-1.518295</td>
#       <td>1.299667</td>
#       <td>-0.332022</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2010-01-02</th>
#       <td>0.365641</td>
#       <td>1.391388</td>
#       <td>0.794097</td>
#       <td>2.043478</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2010-01-03</th>
#       <td>-0.419046</td>
#       <td>0.577045</td>
#       <td>-1.754361</td>
#       <td>-0.527029</td>
# ...

# %%
pd.isnull(df1)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-01-01</th>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2010-01-02</th>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2010-01-03</th>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
# ...

# %%
df.mean(), df.mean(1), df.apply(np.cumsum)
# Out:
# (A    0.236204
#  B    0.272722
#  C    0.046428
#  D   -0.001441
#  dtype: float64, 2010-01-01   -0.333859
#  2010-01-02    1.148651
#  2010-01-03   -0.530848
#  2010-01-04    0.037511
#  2010-01-05    0.063685
#  2010-01-06    0.445728
#  Freq: D, dtype: float64,                    A         B         C         D
#  2010-01-01 -0.784787 -1.518295  1.299667 -0.332022
#  2010-01-02 -0.419146 -0.126906  2.093764  1.711456
#  2010-01-03 -0.838191  0.450139  0.339403  1.184428
#  2010-01-04 -1.943106  1.946974  0.173842  1.108115
#  2010-01-05 -0.151700  1.966716  0.039186 -0.313638
#  2010-01-06  1.417223  1.636333  0.278567 -0.008647)

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    0
# 1    3
# 2    4
# 3    4
# 4    5
# 5    3
# 6    0
# 7    0
# 8    3
# 9    1
# dtype: int32

# %%
s.value_counts()
# Out:
# 3    3
# 0    3
# 4    2
# 5    1
# 1    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.512497</td>
#       <td>1.303813</td>
#       <td>-0.514341</td>
#       <td>0.667770</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-0.544274</td>
#       <td>0.544026</td>
#       <td>0.932778</td>
#       <td>0.309543</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.043849</td>
#       <td>1.567133</td>
#       <td>0.901922</td>
#       <td>-0.767225</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-1.234002</td>
#       <td>-0.796852</td>
# ...

# %%
pieces = [df[3:7], df[:3], df[7:]]
pd.concat(pieces)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>-1.234002</td>
#       <td>-0.796852</td>
#       <td>-0.023712</td>
#       <td>1.193740</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.144294</td>
#       <td>1.365264</td>
#       <td>0.494568</td>
#       <td>-0.569573</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>-1.226382</td>
#       <td>0.194196</td>
#       <td>-0.309946</td>
#       <td>-0.024617</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2.914583</td>
#       <td>1.235050</td>
# ...

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})
pd.merge(left, right1, on='key')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>lval</th>
#       <th>rval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>foo</td>
#       <td>1</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>foo</td>
#       <td>1</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>foo</td>
#       <td>2</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>foo</td>
#       <td>2</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['a', 'b', 'c', 'd'])
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-0.860215</td>
#       <td>-0.892423</td>
#       <td>0.957388</td>
#       <td>-0.297301</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-0.953374</td>
#       <td>0.740673</td>
#       <td>-0.301945</td>
#       <td>-0.209941</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.568728</td>
#       <td>-0.761821</td>
#       <td>-0.902628</td>
#       <td>0.183206</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.415864</td>
#       <td>-1.161530</td>
# ...

# %%
df1 = df.copy()
df.append(df1)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-0.860215</td>
#       <td>-0.892423</td>
#       <td>0.957388</td>
#       <td>-0.297301</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-0.953374</td>
#       <td>0.740673</td>
#       <td>-0.301945</td>
#       <td>-0.209941</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.568728</td>
#       <td>-0.761821</td>
#       <td>-0.902628</td>
#       <td>0.183206</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.415864</td>
#       <td>-1.161530</td>
# ...

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                   'B' : ['one', 'one', 'two', 'three','two', 'two', 'one', 'three'],
                   'C' : np.random.randn(8), 
                   'D' : np.random.randn(8)})
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>foo</td>
#       <td>one</td>
#       <td>0.900994</td>
#       <td>-0.512803</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>bar</td>
#       <td>one</td>
#       <td>-1.052439</td>
#       <td>-0.057414</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>foo</td>
#       <td>two</td>
#       <td>0.030662</td>
#       <td>1.159194</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>bar</td>
#       <td>three</td>
#       <td>0.460573</td>
# ...

# %%
df.groupby('A').sum()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#     <tr>
#       <th>A</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>bar</th>
#       <td>-2.223355</td>
#       <td>1.623073</td>
#     </tr>
#     <tr>
#       <th>foo</th>
#       <td>-0.002052</td>
#       <td>0.732932</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.groupby(['A', 'B']).sum()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#     <tr>
#       <th>A</th>
#       <th>B</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="3" valign="top">bar</th>
#       <th>one</th>
#       <td>-1.052439</td>
#       <td>-0.057414</td>
#     </tr>
#     <tr>
#       <th>three</th>
#       <td>0.460573</td>
#       <td>0.564637</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>-1.631489</td>
#       <td>1.115850</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">foo</th>
#       <th>one</th>
#       <td>1.315277</td>
# ...

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})  
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
df = pd.DataFrame(np.random.randn(5, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')

# %%
df.to_csv("foo.csv")

# %%
pd.read_csv('foo.csv')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2012-01-31</td>
#       <td>0.334896</td>
#       <td>0.903882</td>
#       <td>-0.539699</td>
#       <td>-0.707347</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2012-02-29</td>
#       <td>-0.563684</td>
#       <td>2.027461</td>
#       <td>-0.217035</td>
#       <td>-1.170868</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2012-03-31</td>
#       <td>-1.282614</td>
#       <td>2.604861</td>
#       <td>-0.809002</td>
# ...
